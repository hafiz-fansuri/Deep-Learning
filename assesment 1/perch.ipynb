# %%
# Out:
# Processing c:\kaggle\input\notebooks\kdmitrie\bc26-tensorflow-2-20-0\wheel\tensorboard-2.20.0-py3-none-any.whl
# WARNING: Requirement '/kaggle/input/notebooks/kdmitrie/bc26-tensorflow-2-20-0/wheel/tensorboard-2.20.0-py3-none-any.whl' looks like a filename, but the file does not exist
# WARNING: Ignoring invalid distribution -ransformers (c:\users\fansuri\miniconda3\envs\mv1\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\kaggle\\input\\notebooks\\kdmitrie\\bc26-tensorflow-2-20-0\\wheel\\tensorboard-2.20.0-py3-none-any.whl'
#
# WARNING: Requirement '/kaggle/input/notebooks/kdmitrie/bc26-tensorflow-2-20-0/wheel/tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl' looks like a filename, but the file does not exist
# WARNING: Ignoring invalid distribution -ransformers (c:\users\fansuri\miniconda3\envs\mv1\lib\site-packages)
# ...
